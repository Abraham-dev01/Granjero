# %%
def separar(frase):
    palabras = frase.split()
    for i in range(len(palabras)):
      longitud = len(palabras[i])
      print("Palabra: %s, caracteres: %d" % (palabras[i], longitud))
    return palabras

frase = str(input("Introduce una frase: "))
separar(frase)
# Out:
# Palabra: Hola, caracteres: 4
# Palabra: mi, caracteres: 2
# Palabra: nombre, caracteres: 6
# Palabra: es, caracteres: 2
# Palabra: Abraham, caracteres: 7
# ['Hola', 'mi', 'nombre', 'es', 'Abraham']
