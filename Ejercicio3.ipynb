# %%
mi_lista = [1, 2, 3, 4, 5]

def doble(numero):
    return numero * 2

def aplicar_funcion(funcion, lista):
    resultado = []
    for num in lista:
      resultado.append(doble(num))
    return resultado

resultado = aplicar_funcion(doble, mi_lista)
print(resultado)
# Out:
# [2, 4, 6, 8, 10]
